# %%
class test():
    def __init__(self, hotpot, jps, dogs):
        self.hotpot = hotpot
        self.jps = jps
        self.dogs = dogs
        pass
instance = test(1,1,2)
result = vars(instance)['hotpot']
print result
# Out:
# 1

# %%
x = test(1,1,2)
y = test(2,10,3)
z = [x,y]
m = map(lambda i: vars(i), z)
for ele in m:
    print ele['hotpot']
# Out:
# 1
# 2

# %%
from gensim import models

# %%
model = models.Word2Vec.load("./Workspace/Word2Vec_sz_200_mc_1_sg_by_sentence_big")

# %%
for ele in model.most_similar(u"魯肉飯", topn = 20):
    print ele[0]
# Out:
# 滷肉飯
# 肉燥飯
# 雞肉飯
# 控肉飯
# 火雞肉飯
# 筒仔米糕
# 魯肉
# 焢肉飯
# 今大
# 香菇肉燥飯
# 豬腳飯
# 爌肉飯
# 肉羹湯
# 幼肉
# 焢肉
# 知高飯
# 乾麵
# 魚翅肉羹
# 鴨肉飯
# 李海

# %%
print model[u"魯肉飯"]
# Out:
# [-0.05991678 -0.0083565  -0.30617636  0.01073566  0.541866    0.0109185
#   0.46275204 -0.32620266 -0.27204651 -0.51609147 -0.14763169 -0.04135301
#   0.03998026  0.16377112 -0.49949786  0.27660516 -0.18784714  0.6002599
#   0.29484874 -0.50043064  0.03168576  0.50216973  0.35622233 -0.28791612
#  -0.52049112  0.21258307 -0.29561719  0.06365801 -0.4959029   0.0709312
#  -0.82213116 -0.27539429 -0.44087568  0.26777798  0.11088733 -0.18507768
#  -0.42759204 -0.17456397  0.21653464 -0.55733252 -0.09760261 -0.37868822
#  -0.0923226   0.42927024 -0.18919548 -0.08118736 -0.20923148  0.08231324
#  -0.04093913 -0.17401627  0.34551066 -0.38009623  0.769454   -0.2382728
#  -0.17944393  0.34205535  0.73551822 -0.20834737  0.65726459  0.28587151
#   0.43569225  0.24413629  0.41156095 -0.23469403  0.09763069 -0.51404822
#  -0.35147032  0.00720699 -0.21730348 -0.17353401  0.39880779  0.173566
#   0.00646608  0.17157093  0.13647839 -0.29935142 -0.2351021   0.23979473
# ...
