# %%
# import requests
# from bs4 import BeautifulSoup

# res = requests.get('http://star.gg/special-symbols')
# soup = BeautifulSoup(res.text)
# dic = []
# for ens in soup.select('td'):

# #     print ens.text
#     dic.append(ens.text)
# # print dic
# # for ele in dic:
# #     print ele
# with open('error.txt','w') as f:
#     for g in dic:
#         if(len(g)>0 or u'\uff3f'not in g):
#             print g,len(g),repr(g)
#             f.write(g.encode('utf-8').strip()+",")
# Out:
# 愛心 2 u'\u611b\u5fc3'
# 星星 2 u'\u661f\u661f'
# 箭頭 2 u'\u7bad\u982d'
# 符號圖案 4 u'\u7b26\u865f\u5716\u6848'
# 框線 2 u'\u6846\u7dda'
# 填色方塊 4 u'\u586b\u8272\u65b9\u584a'
# 數字 2 u'\u6578\u5b57'
# 英文 2 u'\u82f1\u6587'
# 貨幣 2 u'\u8ca8\u5e63'
# 標點符號 4 u'\u6a19\u9ede\u7b26\u865f'
# 括號 2 u'\u62ec\u865f'
# 表情 2 u'\u8868\u60c5'
# 音符 2 u'\u97f3\u7b26'
# 圓圈中文字 5 u'\u5713\u5708\u4e2d\u6587\u5b57'
# 數學 2 u'\u6578\u5b78'
# 希臘字母 4 u'\u5e0c\u81d8\u5b57\u6bcd'
# 日文 2 u'\u65e5\u6587'
# 韓文 2 u'\u97d3\u6587'
# 特殊字母 4 u'\u7279\u6b8a\u5b57\u6bcd'
# 注音符號 4 u'\u6ce8\u97f3\u7b26\u865f'
# ❤ 1 u'\u2764'
# ღ 1 u'\u10e6'
# ❥ 1 u'\u2765'
# ♡ 1 u'\u2661'
# ♥ 1 u'\u2665'
#  0 u''
# ★ 1 u'\u2605'
# ✰ 1 u'\u2730'
# ☆ 1 u'\u2606'
# ✩ 1 u'\u2729'
# ✫ 1 u'\u272b'
# ✬ 1 u'\u272c'
# ✭ 1 u'\u272d'
# ✮ 1 u'\u272e'
# ✡ 1 u'\u2721'
#  0 u''
# ↑ 1 u'\u2191'
# ↓ 1 u'\u2193'
# ← 1 u'\u2190'
# → 1 u'\u2192'
# ↖ 1 u'\u2196'
# ↗ 1 u'\u2197'
# ↙ 1 u'\u2199'
# ↘ 1 u'\u2198'
# ↔ 1 u'\u2194'
# ↕ 1 u'\u2195'
# ➻ 1 u'\u27bb'
# ➼ 1 u'\u27bc'
# ...

# %% [markdown]
# ## 第一run

# %%
text=[]
text=['👍','●', '○','^^','◆','▲','✿','★','♥','■','◆','@@','☆','+','。','✔','＊','㊣','▼','◣','◢',
      '==============================','□','►','☉','^_^','‘×’','※','△','◇','♛','~^ ^~',
      '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~','◎','*','Σ( ° △ °|||)︴'
     ,'〒','√','========== ==========','【 】','↖','↘','↗','↗','∥','^o^','ㄌ','ㄍ','ㄛ','ㄉ','╭','❤',
      '✈','￥','❒','✜''👍','●','➽','★','◆','■','▋','▌','❤','▲','♥','☻','㊣','❒','❺','❷','❹','❸','❶','〒','≧',
      '♞','➤','✦','✠','❉','✜','《','》','"',' ','🐻','☀','🎉','➕','🚫','📲','🌟','🌻','☆','★','◎']
for line in open('C:\\Users\\BIG DATA\\weird_mark.txt','r'):
    for ele in line.split(','):
        text.append(ele)
for ele in text:
     print ele,
# Out:
# 👍 ● ○ ^^ ◆ ▲ ✿ ★ ♥ ■ ◆ @@ ☆ + 。 ✔ ＊ ㊣ ▼ ◣ ◢ ============================== □ ► ☉ ^_^ ‘×’ ※ △ ◇ ♛ ~^ ^~ ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ◎ * Σ( ° △ °|||)︴ 〒 √ ========== ========== 【 】 ↖ ↘ ↗ ↗ ∥ ^o^ ㄌ ㄍ ㄛ ㄉ ╭ ❤ ✈ ￥ ❒ ✜👍 ● ➽ ★ ◆ ■ ▋ ▌ ❤ ▲ ♥ ☻ ㊣ ❒ ❺ ❷ ❹ ❸ ❶ 〒 ≧ ♞ ➤ ✦ ✠ ❉ ✜ 《 》 "   🐻 ☀ 🎉 ➕ 🚫 📲 🌟 🌻 ☆ ★ ◎ ﻿❤ ღ ❥ ♡ ♥  ★ ✰ ☆ ✩ ✫ ✬ ✭ ✮ ✡  ↑ ↓ ← → ↖ ↗ ↙ ↘ ↔ ↕ ➻ ➼ ➽ ➸ ➳ ➺ ➻ ➴ ➵ ➶ ➷ ➹ ▶ ➩ ➪ ➫ ➬ ➭ ➮ ➯ ➱ ➲ ➾ ➔ ➘ ➙ ➚ ➛ ➜ ➝ ➞ ➟ ➠ ➡ ➢ ➣ ➤ ➥ ➦ ➧ ➨ ↚ ↛ ↜ ↝ ↞ ↟ ↠ ↠ ↡ ↢ ↣ ↤ ↤ ↥ ↦ ↧ ↨ ⇄ ⇅ ⇆ ⇇ ⇈ ⇉ ⇊ ⇋ ⇌ ⇍ ⇎ ⇏ ⇐ ⇑ ⇒ ⇓ ⇔ ⇖ ⇗ ⇘ ⇙ ⇜ ↩ ↪ ↫ ↬ ↭ ↮ ↯ ↰ ↱ ↲ ↳ ↴ ↵ ↶ ↷ ↸ ↹ ↺ ↻ ↼ ↽ ↾ ↿ ⇀ ⇁ ⇂ ⇃ ⇞ ⇟ ⇠ ⇡ ⇢ ⇣ ⇤ ⇥ ⇦ ⇧ ⇨ ⇩ ⇪ ♞ ♘ ♙ ♟ ♕ ♛ ☬ ♝ ☫ ♚ ☃ ☸ ♗ 〠 ☊ ☋ ❡ ๑ ♨ ❖ ☇ ☈ ۞ ۩ ♤ ♠ ♧ ♣ ◇ ◆ ▧ ◘ ▩ ▣ ◙ ▨ ▤ ▥ ▦ ✠ ☜ ☞ ☎ ☏ ♂ ♀ ☼ ♈ ☄ ﺴ ◈ ♦ ◊ ₪ ✌ ☃ ↂ ☁ ☂ ¤ ☽ ☾ ✙ ✈ ✉ ✁ ㍿ № ✎ ✐ ◎ ○ ● ⊕ ⊙ ◕ ◑ ◐ ™ ℗ ஐ ℡ ✔ ☑ ☒ ☢ ▪ ▫ □ ■ ❈ ❉ ❧ ❦ ❁ ❀ ✳ ✲ ✱ ❈ ❃ ❂ ❁ ❀ ✿ ✾ ✽ ✼ ✻ ✺ ✹ ✸ ✷ ✶ ✵ ✴ ❄ ❅ ❆ ❇ ┋ ┇ ┅ ﹉ ﹊ ﹍ ﹍ ∈ ∋ Π ▬ ☍ △ ▽ ▲ ▼ ► ◄ 卍 卐 〄 ☌ ❣ ✆ ✇ ✑ ✒ ✓ ✕ ✖ ✢ ✣ ✤ ✥ ✟ ✧ ❍ ❏ ❐ ❒ ✗ ✘ ✚ ✜ ✝      ┬ ┴ ├ ─ ┼ ┤ ┌ ┐ ╞ ═ ╪ ╡ │ ▕ └ ┘ ╭ 
# ...

# %% [markdown]
# ## 第二run 清理資料

# %%
text_f='<![CDATA[/varcontext= 123'
res=text_f.replace('<![CDATA[/varcontext=','')
print res
# Out:
#  123

# %%
import re
# text=['👍','●','➽','★','◆','■','▋','▌','❤','▲','♥','☻','㊣','❒','❺','❷','❹','❸','❶','〒','≧',
#       '○','^^','◆','✿','★','◆','@@','☆','+','。','✔','＊','▼','◣','◢','♞','➤','✦','✠','❉',
#       '==============================','□','・','ㄧ','►','☉','^_^','‘×’','※','△','◇','♛','#','~^ ^~'
#       '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~','◎','*','Σ( ° △ °|||)︴'
#      ,'√','========== ==========','【 】','↖','↘','↗','↗','∥','^o^','ㄌ','ㄍ','ㄛ','ㄉ','╭',
#       '✈','￥','✜']

# text2='i am 👍'
# if text in text2:
#     print 'ok'
# # text2=text.encode('utf-8')
# import os, sys
# # Open a file
#path = "C:\\Users\\BIG DATA\\00050004_final"
# dirs = os.listdir( path )
# for file in dirs:
content=''
a=0
with open('C:/Users/BIG DATA/00050004_clean/00050004&o=15v2.txt','w')as w:
    for line in open('C:/Users/BIG DATA/00050004_final/00050004&o=15.txt','r'):
#         for ele in f.readlines():
        content=''
        pattern = re.sub(r'\{.*\}','',line)
#                 pattern2 = pattern.replace(r'\/<![CDATA[/var context =','')
#         pattern2 = re.sub(r'/<![CDATA[/varcontext=','',pattern)
#         pattern2 = pattern.replace('<![CDATA[/varcontext=','')
        a+=1
        content=content+pattern
#         for element in text_f:
# #             print element
#             if element in content:
#                 content=content.replace(element, "")
        
        
        for element in text:
#             print element
            if element in content:
                content=content.replace(element, "")
#         print content
#         w.write(content)


#         w.write(pattern)

        #解決left_num中'缺貨中'的問題
        content=content.replace('<![CDATA[/varcontext=', "")
        pattern_final = re.sub(r'缺貨中','0',content)
        pattern_final = re.sub(r'\'','0',pattern_final)
#             pattern_final = re.sub(r'_|\\n','_|',pattern_final)

        w.write(pattern_final)
print a
# Out:
# 2967

# %% [markdown]
# ## 第3run檔案合為一

# %%
import os, sys
# Open a file
path = "C:\\Users\\BIG DATA\\00080001_clean"
dirs = os.listdir( path )

for file in dirs:
    print file
    content=''
    with open('C:\\Users\\BIG DATA\\00080001_clean\\notebook_data.txt'.format(file),'a')as w:
        with open('C:\\Users\\BIG DATA\\00080001_clean\\{}'.format(file),'r')as f:
            for ele in f.readlines():
                content=content+ele
                
        w.write(content)
# Out:
# 0008000100010005.txt.txt
# 0008000100020005.txt.txt
# 0008000100030005.txt.txt
# 0008000100040005.txt.txt
# 0008000100050005.txt.txt
# 0008000100060001.txt.txt
# 0008000100070005.txt.txt
# 000800010008.txt.txt
# 0008000100090009.txt.txt
# 0008000100100007.txt.txt
# 0008000100110007.txt.txt
# 0008000100120009.txt.txt
# 0008000100140009.txt.txt
# 0008000100150009.txt.txt
# 0008000100160009.txt.txt
# 0008000100170006.txt.txt
# 0008000100180007.txt.txt
# 0008000100190009.txt.txt
# 0008000100200009.txt.txt
# 0008000100210001.txt.txt
# 0008000100220001.txt.txt
# 0008000100230001.txt.txt
# 0008000100240001.txt.txt
# 0008000100250001.txt.txt
# 0008000200030001.txt.txt
# 0008000200030002.txt.txt
# 0008000200030004.txt.txt
# 0008000500170001.txt.txt
# 0008000500170002.txt.txt
# 0008000500170003.txt.txt
# 0008000500170004.txt.txt
# 0008000500170005.txt.txt
# 0008000500170006.txt.txt
# 0008000500170007.txt.txt
# 0008000500170008.txt.txt
# 0008000500170009.txt.txt
# 0008000500170010.txt.txt
# ...

# %%
for line in open('C:\\Users\\BIG DATA\\00080001_clean\\test.txt','r'):
    print line.decode('utf-8'),repr(line.decode('utf-8'))
# Out:
# 　注意事 u'\ufeff\xa0\r\u3000\u6ce8\u610f\u4e8b'

# %% [markdown]
# ## 第4run整理格式(僅針對格式非常亂的 )

# %%
with open('C:\\Users\\BIG DATA\\00050004_clean\\00050004&o=15v3.txt','w')as w:
#     oldlist=[]
    a=0
    
    for line in open('00080001_clean/0008000500210018v2.txt','r'):
        line=line.replace('\r','')
#         for ele in line.split('_|')[:20]:
#             print ele
        a+=1
#         a+=1
#         print line
#         mylist="_|".join(oldlist)+"_|"+line
        mylist=line.split('_|')
        while(len(mylist)>=13):
            print len(mylist),
            mystr=""
            for ele in mylist[:13]:
                mystr+=ele+'_|'
#             print ele
#             print mystr
            w.write(mystr+'\n')
            mylist=mylist[13:]
#         if(len(mylist)>14):
#             reallist=mylist[:14]
#             print len(reallist)
#             oldlist=mylist[14:]
print a
#         print line
#         print mylist[4]
#         if(a>10):
#             break
#         if(len(mylist)==14):
#             print mylist[4]
#             if(int(mylist[4]) < 1000000):
#                 print true
#                 w.write(line)
# Out:
# 38532 38519 38506 38493 38480 38467 38454 38441 38428 38415 38402 38389 38376 38363 38350 38337 38324 38311 38298 38285 38272 38259 38246 38233 38220 38207 38194 38181 38168 38155 38142 38129 38116 38103 38090 38077 38064 38051 38038 38025 38012 37999 37986 37973 37960 37947 37934 37921 37908 37895 37882 37869 37856 37843 37830 37817 37804 37791 37778 37765 37752 37739 37726 37713 37700 37687 37674 37661 37648 37635 37622 37609 37596 37583 37570 37557 37544 37531 37518 37505 37492 37479 37466 37453 37440 37427 37414 37401 37388 37375 37362 37349 37336 37323 37310 37297 37284 37271 37258 37245 37232 37219 37206 37193 37180 37167 37154 37141 37128 37115 37102 37089 37076 37063 37050 37037 37024 37011 36998 36985 36972 36959 36946 36933 36920 36907 36894 36881 36868 36855 36842 36829 36816 36803 36790 36777 36764 36751 36738 36725 36712 36699 36686 36673 36660 36647 36634 36621 36608 36595 36582 36569 36556 36543 36530 36517 36504 36491 36478 36465 36452 36439 36426 36413 36400 36387 36
# ...

# %% [markdown]
# ## 第5run排除金額超過1000000(避免超過int範圍)，列數小於14

# %%
with open('C:\\Users\\BIG DATA\\00050004_clean\\00050004&o=15v3.txt','w')as w:
    for line in open('C:\\Users\\BIG DATA\\00050004_clean\\00050004&o=15v2.txt','r'):
#         a+=1
#         print line
        mylist=line.split('_|')
#         print line
#         print mylist[4]
#         if(a>10):
#             break
        if(len(mylist)==14):
#             print mylist[4]
            if(int(mylist[4]) < 1000000):
#                 print true
                w.write(line)

# %% [markdown]
# ## 第6run增加欄位title_id (primary key)

# %%
a=0
with open('C:\\Users\\BIG DATA\\00050004_clean\\00050004&o=15v4.txt','w') as w:
    for line in open('C:\\Users\\BIG DATA\\00050004_clean\\00050004&o=15v3.txt','r'):
        a+=1
    #     print line
        mylist=line.split('_|')
        mylist_id=mylist[1].split('show?')[1]
#         mylist_log=mylist[6].replace('上次登入：','')
        mylist=mylist_id+'_|'+line
        mylist=mylist.replace('上次登入：','')
#         print mylist
        w.write(mylist)
#         if(a>10):
#             break

# %% [markdown]
# # 第7run刪除(\)一定要執行!

# %%
with open('C:\\Users\\BIG DATA\\00050004_clean\\00050004&o=15v5.txt','w') as w:
    for line in open('C:\\Users\\BIG DATA\\00050004_clean\\00050004&o=15v4.txt','r'):
        line=line.replace('\r','')
        line=line.replace('\\','/')
        w.write(line)

# %%
import os, sys

# Open a file
path = "C:\\Users\\BIG DATA\\ETLclass\\project\\itemlist_backup\\sujen\\00120004"
dirs = os.listdir( path )

# This would print all the files and directories
for file in dirs:
    print file
# Out:
# 0012000400010001.txt
# 0012000400010002.txt
# 0012000400010003.txt
# 0012000400010005.txt
# 0012000400010006.txt
# 0012000400010007.txt
# 0012000400010008.txt
# 0012000400010009.txt
# 0012000400010010.txt
# 0012000400010011.txt
# 0012000400010012.txt
# 0012000400010013.txt
# 0012000400010014.txt
# 0012000400010015.txt
# 0012000400010016.txt
# 0012000400010017.txt
# 0012000400010018.txt
# 0012000400010019.txt
# 0012000400010020.txt
# 0012000400010021.txt
# 0012000400010022.txt
# 0012000400010023.txt
# 0012000400010024.txt
# 0012000400010025.txt
# 0012000400020001.txt
# 0012000400020002.txt
# 0012000400020003.txt
# 0012000400020004.txt
# 0012000400020005.txt
# 0012000400020006.txt
# 0012000400020007.txt
# 0012000400020008.txt
# 0012000400020009.txt
# 0012000400020010.txt
# 0012000400020011.txt
# 0012000400020012.txt
# 0012000400020013.txt
# 0012000400020014.txt
# 0012000400020015.txt
# 0012000400020016.txt
# 0012000400020017.txt
# 0012000400020018.txt
# 0012000400020019.txt
# ...

# %%
print type(content)
# Out:
# <type 'str'>

# %%
text='<![CDATA[/varcontext= 123'
res=text.replace('<![CDATA[/varcontext=','')
print res
# Out:
#  123

# %%
print '\xe4\xb8\x8a\xe6\xac\xa1\xe7\x99\xbb\xe5\x85\xa5\xef\xbc\x9a2016-06-25'
# Out:
# 上次登入：2016-06-25

# %%
text='<![CDATA[/varcontext='
print repr(text)
text1='<![CDATA[/varcontext='
print repr(text1)
# Out:
# '<![CDATA[/varcontext='
# '<![CDATA[/varcontext='
